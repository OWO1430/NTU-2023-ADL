# %%
rouge1_f = [0.21599204342319459, 0.25809701064302676, 0.26394862545139647, 0.26760147155470604, 0.27908864339691597]
rouge2_f = [0.08435029677180907, 0.10295725362680397, 0.10641573108033141, 0.10684148451468908, 0.11315112049452766]
rougel_f = [0.19688824764772492, 0.23331483737036654, 0.23574648056010605, 0.23897989451971935, 0.24887883031267405]

# %% [markdown]
# epoch1:
# ```
# {
#   "rouge-1": {"r": 0.185428470927207, "p": 0.2953388817956552, "f": 0.21599204342319459},
#   "rouge-2": {"r": 0.0726613163249199, "p": 0.11760719556749724, "f": 0.08435029677180907},
#   "rouge-l": {"r": 0.16892198878959813, "p": 0.2696895899717178, "f": 0.19688824764772492}
# }
# ```
# epoch2:
# ```
# {
#   "rouge-1": {"r": 0.243095631215878, "p": 0.3045243014609699, "f": 0.25809701064302676},
#   "rouge-2": {"r": 0.09875670340195346, "p": 0.11950972706507296, "f": 0.10295725362680397},
#   "rouge-l": {"r": 0.2194985586052127, "p": 0.2761924821383622, "f": 0.23331483737036654}
# }
# ```
# epoch3:
# ```
# {
#   "rouge-1": {"r": 0.2549932455708806, "p": 0.29858008676895176, "f": 0.26394862545139647},
#   "rouge-2": {"r": 0.10444614913318627, "p": 0.11851974991208652, "f": 0.10641573108033141},
#   "rouge-l": {"r": 0.22766848789765795, "p": 0.2672338759681655, "f": 0.23574648056010605}
# }
# ```
#
# epoch4:
# ```
# {
#   "rouge-1": {"r": 0.25799062822428354, "p": 0.3024376219074938, "f": 0.26760147155470604},
#   "rouge-2": {"r": 0.10464331932444766, "p": 0.11909269803096778, "f": 0.10684148451468908},
#   "rouge-l": {"r": 0.230360955806019, "p": 0.2704452498708521, "f": 0.23897989451971935}
# }
# ```
# epoch5:
# ```
# {
#   "rouge-1": {"r": 0.2680423934296503, "p": 0.3150465239407713, "f": 0.27908864339691597},
#   "rouge-2": {"r": 0.1104502628859502, "p": 0.12593803117302035, "f": 0.11315112049452766},
#   "rouge-l": {"r": 0.23910701462366268, "p": 0.2812092476399294, "f": 0.24887883031267405}
#   }
# ```

# %%
import matplotlib.pyplot as plt

epochs = [1, 2, 3, 4, 5]
rouge1_f = [0.21599204342319459, 0.25809701064302676, 0.26394862545139647, 0.26760147155470604, 0.27908864339691597]
rouge2_f = [0.08435029677180907, 0.10295725362680397, 0.10641573108033141, 0.10684148451468908, 0.11315112049452766]
rougel_f = [0.19688824764772492, 0.23331483737036654, 0.23574648056010605, 0.23897989451971935, 0.24887883031267405]

plt.figure(figsize=(18, 5))

# ROUGE-1 F1 Score Plot
plt.subplot(1, 3, 1)
plt.plot(epochs, rouge1_f, marker='o', linestyle='-', color='blue')
plt.title('Epoch vs ROUGE-1 F1 Score')
plt.xlabel('Epoch')
plt.ylabel('F-Score')
plt.grid(True)

# ROUGE-2 F1 Score Plot
plt.subplot(1, 3, 2)
plt.plot(epochs, rouge2_f, marker='o', linestyle='-', color='orange')
plt.title('Epoch vs ROUGE-2 F1 Score')
plt.xlabel('Epoch')
plt.ylabel('F-Score')
plt.grid(True)

# ROUGE-L F1 Score Plot
plt.subplot(1, 3, 3)
plt.plot(epochs, rougel_f, marker='o', linestyle='-', color='green')
plt.title('Epoch vs ROUGE-L F1 Score')
plt.xlabel('Epoch')
plt.ylabel('F-Score')
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()
